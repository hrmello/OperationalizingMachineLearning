# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.13.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code RNB2GMP69 to authenticate.
# You have logged in. Now let us find all the subscriptions to which you have access...
# Interactive authentication successfully completed.
# quick-starts-ws-117869
# aml-quickstarts-117869
# southcentralus
# bc4ac49b-f3f0-45bb-995b-638f2c80696f

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'ml-experiment-1'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: ml-experiment-1,
# Workspace: quick-starts-ws-117869)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "auto-ml"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS12_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           min_nodes = 1,
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Creating
# Succeeded..........................
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "BankMarketing Dataset"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 15,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [e450edf0][7b008bc2-3122-4f13-9298-f235487d3caf], (This step will run and generate new outputs)
# Submitted PipelineRun 632408b3-1dda-4d1f-9e02-bd9c1a2ddd81
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/ml-experiment-1/runs/632408b3-1dda-4d1f-9e02-bd9c1a2ddd81?wsid=/subscriptions/bc4ac49b-f3f0-45bb-995b-638f2c80696f/resourcegroups/aml-quickstarts-117869/workspaces/quick-starts-ws-117869

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: 632408b3-1dda-4d1f-9e02-bd9c1a2ddd81
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/ml-experiment-1/runs/632408b3-1dda-4d1f-9e02-bd9c1a2ddd81?wsid=/subscriptions/bc4ac49b-f3f0-45bb-995b-638f2c80696f/resourcegroups/aml-quickstarts-117869/workspaces/quick-starts-ws-117869
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: dd000e88-6004-4743-aa71-8b012b896dc8
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/ml-experiment-1/runs/dd000e88-6004-4743-aa71-8b012b896dc8?wsid=/subscriptions/bc4ac49b-f3f0-45bb-995b-638f2c80696f/resourcegroups/aml-quickstarts-117869/workspaces/quick-starts-ws-117869
# StepRun( automl_module ) Status: NotStarted
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': 'dd000e88-6004-4743-aa71-8b012b896dc8', 'target': 'auto-ml', 'status': 'Completed', 'startTimeUtc': '2020-09-30T18:35:01.146246Z', 'endTimeUtc': '2020-09-30T18:52:30.201349Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': 'f63ef9c8-9b93-4972-af8f-e2a57422785d', 'StepType': 'AutoMLStep', 'azureml.moduleid': '7b008bc2-3122-4f13-9298-f235487d3caf', 'azureml.nodeid': 'e450edf0', 'azureml.pipelinerunid': '632408b3-1dda-4d1f-9e02-bd9c1a2ddd81', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'auto-ml', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "bc4ac49b-f3f0-45bb-995b-638f2c80696f", "resource_group": "aml-quickstarts-117869", "workspace_name": "quick-starts-ws-117869", "region": "southcentralus", "compute_target": null, "spark_service": null, "azure_service": null, "_local_managed_run_id": null, "many_models": false, "iterations": 1000, "primary_metric": "AUC_weighted", "task_type": "classification", "data_script": null, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 5, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 15, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["RandomForest", "LightGBM", "XGBoostClassifier", "SVM", "SGD", "MultinomialNaiveBayes", "KNN", "AveragedPerceptronClassifier", "TensorFlowDNN", "LinearSVM", "TensorFlowLinearClassifier", "GradientBoosting", "LogisticRegression", "BernoulliNaiveBayes", "DecisionTree", "ExtremeRandomTrees"], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_DS12_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true, "scenario": "SDK-1.13.0"}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"7a52f855-563a-4efb-b954-fd602be94fe4\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', 'root_attribution': 'azureml.StepRun', 'snapshotId': 'f63ef9c8-9b93-4972-af8f-e2a57422785d', 'SetupRunId': 'dd000e88-6004-4743-aa71-8b012b896dc8_setup', 'SetupRunContainerId': 'dcid.dd000e88-6004-4743-aa71-8b012b896dc8_setup', 'ClientSdkVersion': '1.13.0', 'FeaturizationRunJsonPath': 'featurizer_container.json', 'FeaturizationRunId': 'dd000e88-6004-4743-aa71-8b012b896dc8_featurize', 'ProblemInfoJsonString': '{"dataset_num_categorical": 0, "is_sparse": true, "subsampling": false, "dataset_classes": 2, "dataset_features": 132, "dataset_samples": 29655, "single_frequency_class_detected": false}', 'ModelExplainRunId': 'dd000e88-6004-4743-aa71-8b012 ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '632408b3-1dda-4d1f-9e02-bd9c1a2ddd81', 'status': 'Completed', 'startTimeUtc': '2020-09-30T18:29:30.724019Z', 'endTimeUtc': '2020-09-30T18:55:55.080452Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg117869.blob.core.windows.net/azureml/ExperimentRun/dcid.632408b3-1dda-4d1f-9e02-bd9c1a2ddd81/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=x8g1o9BniT%2FWaopqJR%2F3AZHa%2Bxv14YrJSCTiD3Jnk30%3D&st=2020-09-30T18%3A19%3A52Z&se=2020-10-01T02%3A29%3A52Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg117869.blob.core.windows.net/azureml/ExperimentRun/dcid.632408b3-1dda-4d1f-9e02-bd9c1a2ddd81/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=j5zvBcwUUuocWxyfYIekw9wkGVsIkSYWHmQl5xnEhbo%3D&st=2020-09-30T18%3A19%3A52Z&se=2020-10-01T02%3A29%3A52Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg117869.blob.core.windows.net/azureml/ExperimentRun/dcid.632408b3-1dda-4d1f-9e02-bd9c1a2ddd81/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=TOEcolsvu%2BrGqOR%2BXtRoo1t1qJWjzNogq7SDhEu8OSA%3D&st=2020-09-30T18%3A19%3A52Z&se=2020-10-01T02%3A29%3A52Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/dd000e88-6004-4743-aa71-8b012b896dc8/metrics_data
# Downloaded azureml/dd000e88-6004-4743-aa71-8b012b896dc8/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  dd000e88-6004-4743-aa71-8b012b896dc8_11  \
# precision_score_weighted                            [0.9165430246859613]
# average_precision_score_weighted                    [0.9372772594704627]
# recall_score_macro                                  [0.8549528847988411]
# precision_score_micro                               [0.8075872534142641]
# accuracy                                            [0.8075872534142641]
# AUC_weighted                                         [0.921600008891408]
# recall_score_micro                                  [0.8075872534142641]
# weighted_accuracy                                   [0.7958276483601238]
# average_precision_score_macro                       [0.7568787148451943]
# balanced_accuracy                                   [0.8549528847988411]
# AUC_macro                                           [0.9216000088914081]
# AUC_micro                                           [0.8672452168066297]
# log_loss                                            [1.1465791520698023]
# recall_score_weighted                               [0.8075872534142641]
# f1_score_macro                                      [0.6979773883876936]
# average_precision_score_micro                       [0.8386518260247651]
# matthews_correlation                                [0.4956247765075287]
# precision_score_macro                               [0.6730116373243092]
# norm_macro_recall                                   [0.7099057695976823]
# f1_score_weighted                                   [0.8391725646461019]
# f1_score_micro                                       [0.807587253414264]
#
#                                  dd000e88-6004-4743-aa71-8b012b896dc8_18  \
# precision_score_weighted                            [0.9059478042662047]
# average_precision_score_weighted                    [0.9357610599114157]
# recall_score_macro                                  [0.8196456588626037]
# precision_score_micro                               [0.8458270106221548]
# accuracy                                            [0.8458270106221548]
# AUC_weighted                                        [0.9055176744522061]
# recall_score_micro                                  [0.8458270106221548]
# weighted_accuracy                                   [0.8523271320704692]
# average_precision_score_macro                       [0.7594181556130163]
# balanced_accuracy                                   [0.8196456588626037]
# AUC_macro                                            [0.905517674452206]
# AUC_micro                                           [0.9052589452451293]
# log_loss                                            [0.4089680857770765]
# recall_score_weighted                               [0.8458270106221548]
# f1_score_macro                                      [0.7203790867492036]
# average_precision_score_micro                       [0.8827140077538886]
# matthews_correlation                               [0.48810333579248644]
# precision_score_macro                               [0.6863351337692966]
# norm_macro_recall                                   [0.6392913177252073]
# f1_score_weighted                                   [0.8657213347524371]
# f1_score_micro                                      [0.8458270106221548]
#
#                                  dd000e88-6004-4743-aa71-8b012b896dc8_4  \
# precision_score_weighted                           [0.8850071880851512]
# average_precision_score_weighted                   [0.9375074479217179]
# recall_score_macro                                 [0.6472463494286345]
# precision_score_micro                              [0.9013657056145675]
# accuracy                                           [0.9013657056145675]
# AUC_weighted                                       [0.9168607031251448]
# recall_score_micro                                 [0.9013657056145675]
# weighted_accuracy                                  [0.9644566679432587]
# average_precision_score_macro                      [0.7622632090422067]
# balanced_accuracy                                  [0.6472463494286345]
# AUC_macro                                          [0.9168607031251447]
# AUC_micro                                          [0.9700552407312315]
# log_loss                                          [0.30825453081177473]
# recall_score_weighted                              [0.9013657056145675]
# f1_score_macro                                     [0.6833856207179263]
# average_precision_score_micro                      [0.9693252341896396]
# matthews_correlation                              [0.39644539168484744]
# precision_score_macro                              [0.7668469357610914]
# norm_macro_recall                                  [0.2944926988572689]
# f1_score_weighted                                  [0.8872536079456921]
# f1_score_micro                                     [0.9013657056145675]
#
#                                  dd000e88-6004-4743-aa71-8b012b896dc8_0  \
# precision_score_weighted                           [0.9072720074188747]
# average_precision_score_weighted                   [0.9531771295804466]
# recall_score_macro                                 [0.7513392683482543]
# precision_score_micro                              [0.9116843702579667]
# accuracy                                           [0.9116843702579667]
# AUC_weighted                                       [0.9450464668693167]
# recall_score_micro                                 [0.9116843702579667]
# weighted_accuracy                                  [0.9514937218005303]
# average_precision_score_macro                      [0.8151093723721079]
# balanced_accuracy                                  [0.7513392683482543]
# AUC_macro                                          [0.9450464668693166]
# AUC_micro                                           [0.979695082216353]
# log_loss                                          [0.17775706110025447]
# recall_score_weighted                              [0.9116843702579667]
# f1_score_macro                                     [0.7653697272147331]
# average_precision_score_micro                      [0.9806603102489483]
# matthews_correlation                               [0.5323740218566827]
# precision_score_macro                              [0.7819118765348991]
# norm_macro_recall                                  [0.5026785366965085]
# f1_score_weighted                                  [0.9091539479147899]
# f1_score_micro                                     [0.9116843702579667]
#
#                                  dd000e88-6004-4743-aa71-8b012b896dc8_22  \
# precision_score_weighted                            [0.8780703269528493]
# average_precision_score_weighted                    [0.9094257810566283]
# recall_score_macro                                  [0.7351652412628022]
# precision_score_micro                               [0.7441578148710167]
# accuracy                                            [0.7441578148710167]
# AUC_weighted                                        [0.8166105396529015]
# recall_score_micro                                  [0.7441578148710167]
# weighted_accuracy                                   [0.7463904276529362]
# average_precision_score_macro                       [0.7062503345367936]
# balanced_accuracy                                   [0.7351652412628022]
# AUC_macro                                           [0.8166105396529015]
# AUC_micro                                           [0.8231742120884866]
# log_loss                                            [0.5770970105872398]
# recall_score_weighted                               [0.7441578148710167]
# f1_score_macro                                      [0.6130442287109443]
# average_precision_score_micro                       [0.8009367238337364]
# matthews_correlation                                [0.3218771314575085]
# precision_score_macro                               [0.6101405199158807]
# norm_macro_recall                                   [0.4703304825256045]
# f1_score_weighted                                   [0.7878395570797165]
# f1_score_micro                                      [0.7441578148710167]
#
#                                  dd000e88-6004-4743-aa71-8b012b896dc8_24  \
# precision_score_weighted                            [0.8486862398357069]
# average_precision_score_weighted                    [0.9057247574484512]
# recall_score_macro                                  [0.5527612453158024]
# precision_score_micro                               [0.8849772382397572]
# accuracy                                            [0.8849772382397572]
# AUC_weighted                                        [0.8328415273216299]
# recall_score_micro                                  [0.8849772382397572]
# weighted_accuracy                                   [0.9674574829922197]
# average_precision_score_macro                       [0.6643619367813893]
# balanced_accuracy                                   [0.5527612453158024]
# AUC_macro                                           [0.8328415273216299]
# AUC_micro                                           [0.9499886018499544]
# log_loss                                            [0.2996115942779301]
# recall_score_weighted                               [0.8849772382397572]
# f1_score_macro                                      [0.5666954309243181]
# average_precision_score_micro                       [0.9460320737377381]
# matthews_correlation                               [0.19213028725485287]
# precision_score_macro                               [0.6749108036575107]
# norm_macro_recall                                  [0.10552249063160479]
# f1_score_weighted                                   [0.8548847302534887]
# f1_score_micro                                      [0.8849772382397572]
#
#                                  dd000e88-6004-4743-aa71-8b012b896dc8_33  \
# precision_score_weighted                             [0.916564729149542]
# average_precision_score_weighted                    [0.9376027037825725]
# recall_score_macro                                  [0.8549866906734686]
# precision_score_micro                               [0.8433990895295903]
# accuracy                                            [0.8433990895295903]
# AUC_weighted                                        [0.9244276619116157]
# recall_score_micro                                  [0.8433990895295903]
# weighted_accuracy                                   [0.8405222016048728]
# average_precision_score_macro                       [0.7556013637106125]
# balanced_accuracy                                   [0.8549866906734686]
# AUC_macro                                           [0.9244276619116156]
# AUC_micro                                             [0.91058342409638]
# log_loss                                            [0.4024815154367649]
# recall_score_weighted                               [0.8433990895295903]
# f1_score_macro                                      [0.7297057544239853]
# average_precision_score_micro                       [0.8830247627227907]
# matthews_correlation                                [0.5246423870308218]
# precision_score_macro                               [0.6938450380683319]
# norm_macro_recall                                   [0.7099733813469371]
# f1_score_weighted                                    [0.865744059461436]
# f1_score_micro                                      [0.8433990895295903]
#
#                                  dd000e88-6004-4743-aa71-8b012b896dc8_2  \
# precision_score_weighted                           [0.8842804744127534]
# average_precision_score_weighted                   [0.9354602065448828]
# recall_score_macro                                 [0.5431775114060095]
# precision_score_micro                              [0.8952959028831563]
# accuracy                                           [0.8952959028831563]
# AUC_weighted                                        [0.905428760370994]
# recall_score_micro                                 [0.8952959028831563]
# weighted_accuracy                                  [0.9827173748456048]
# average_precision_score_macro                      [0.7587820781043253]
# balanced_accuracy                                  [0.5431775114060095]
# AUC_macro                                          [0.9054287603709941]
# AUC_micro                                          [0.9687998323666014]
# log_loss                                          [0.23924377374737288]
# recall_score_weighted                              [0.8952959028831563]
# f1_score_macro                                     [0.5523748321073378]
# average_precision_score_micro                      [0.9696010658154067]
# matthews_correlation                               [0.2427567252930339]
# precision_score_macro                              [0.8412125071362698]
# norm_macro_recall                                  [0.0863550228120189]
# f1_score_weighted                                  [0.8564140755101699]
# f1_score_micro                                     [0.8952959028831563]
#
#                                  dd000e88-6004-4743-aa71-8b012b896dc8_25  \
# precision_score_weighted                             [0.788565560086672]
# average_precision_score_weighted                    [0.9189380242550522]
# recall_score_macro                                                 [0.5]
# precision_score_micro                               [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
# AUC_weighted                                        [0.8802313433250533]
# recall_score_micro                                  [0.8880121396054628]
# weighted_accuracy                                   [0.9843450583187134]
# average_precision_score_macro                       [0.7103613738321392]
# balanced_accuracy                                                  [0.5]
# AUC_macro                                           [0.8802313433250533]
# AUC_micro                                           [0.9636375526444859]
# log_loss                                            [0.3497026042726693]
# recall_score_weighted                               [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# average_precision_score_micro                       [0.9607664043621833]
# matthews_correlation                                               [0.0]
# precision_score_macro                               [0.4440060698027314]
# norm_macro_recall                                                  [0.0]
# f1_score_weighted                                   [0.8353395018439429]
# f1_score_micro                                      [0.8880121396054628]
#
#                                  dd000e88-6004-4743-aa71-8b012b896dc8_26  ...  \
# precision_score_weighted                            [0.8861130607726714]  ...
# average_precision_score_weighted                    [0.9380450357744283]  ...
# recall_score_macro                                  [0.6634824311332655]  ...
# precision_score_micro                               [0.9007587253414264]  ...
# accuracy                                            [0.9007587253414264]  ...
# AUC_weighted                                        [0.9196642752483576]  ...
# recall_score_micro                                  [0.9007587253414264]  ...
# weighted_accuracy                                   [0.9596680109781542]  ...
# average_precision_score_macro                       [0.7618527794825483]  ...
# balanced_accuracy                                   [0.6634824311332655]  ...
# AUC_macro                                           [0.9196642752483575]  ...
# AUC_micro                                           [0.9695320771574165]  ...
# log_loss                                           [0.22638338125030225]  ...
# recall_score_weighted                               [0.9007587253414264]  ...
# f1_score_macro                                      [0.6960957113833692]  ...
# average_precision_score_micro                         [0.96746370064992]  ...
# matthews_correlation                               [0.41133310105052395]  ...
# precision_score_macro                               [0.7587356311729888]  ...
# norm_macro_recall                                   [0.3269648622665311]  ...
# f1_score_weighted                                   [0.8896324446269905]  ...
# f1_score_micro                                      [0.9007587253414264]  ...
#
#                                  dd000e88-6004-4743-aa71-8b012b896dc8_5  \
# precision_score_weighted                            [0.877014103638037]
# average_precision_score_weighted                   [0.9317492398938888]
# recall_score_macro                                 [0.5942781010175104]
# precision_score_micro                              [0.8977238239757208]
# accuracy                                           [0.8977238239757208]
# AUC_weighted                                       [0.9007538246947746]
# recall_score_micro                                 [0.8977238239757208]
# weighted_accuracy                                  [0.9730611889183236]
# average_precision_score_macro                      [0.7415501691087147]
# balanced_accuracy                                  [0.5942781010175104]
# AUC_macro                                          [0.9007538246947746]
# AUC_micro                                          [0.9683810251887602]
# log_loss                                           [0.2405675570210902]
# recall_score_weighted                              [0.8977238239757208]
# f1_score_macro                                     [0.6263947343363969]
# average_precision_score_micro                      [0.9696637870218252]
# matthews_correlation                              [0.31999379338174755]
# precision_score_macro                               [0.771526544069397]
# norm_macro_recall                                 [0.18855620203502088]
# f1_score_weighted                                  [0.8734704046383025]
# f1_score_micro                                     [0.8977238239757208]
#
#                                  dd000e88-6004-4743-aa71-8b012b896dc8_30  \
# precision_score_weighted                             [0.896276493147234]
# average_precision_score_weighted                    [0.9473883104711966]
# recall_score_macro                                  [0.6855164518835892]
# precision_score_micro                               [0.9083459787556905]
# accuracy                                            [0.9083459787556905]
# AUC_weighted                                        [0.9298458637354657]
# recall_score_micro                                  [0.9083459787556905]
# weighted_accuracy                                   [0.9636685228413189]
# average_precision_score_macro                       [0.7969160199391022]
# balanced_accuracy                                   [0.6855164518835892]
# AUC_macro                                           [0.9298458637354658]
# AUC_micro                                           [0.9760192133664609]
# log_loss                                           [0.22016323531640344]
# recall_score_weighted                               [0.9083459787556905]
# f1_score_macro                                      [0.7214524367768216]
# average_precision_score_micro                       [0.9771015060033911]
# matthews_correlation                                [0.4619789239568743]
# precision_score_macro                               [0.7876086244823646]
# norm_macro_recall                                  [0.37103290376717846]
# f1_score_weighted                                    [0.898513121045057]
# f1_score_micro                                      [0.9083459787556905]
#
#                                  dd000e88-6004-4743-aa71-8b012b896dc8_14  \
# precision_score_weighted                             [0.788565560086672]
# average_precision_score_weighted                      [0.92506743234113]
# recall_score_macro                                                 [0.5]
# precision_score_micro                               [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
# AUC_weighted                                        [0.8940144151954165]
# recall_score_micro                                  [0.8880121396054628]
# weighted_accuracy                                   [0.9843450583187134]
# average_precision_score_macro                       [0.7159615235004386]
# balanced_accuracy                                                  [0.5]
# AUC_macro                                           [0.8940144151954166]
# AUC_micro                                           [0.9663789113500245]
# log_loss                                            [0.2439957103053197]
# recall_score_weighted                               [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# average_precision_score_micro                       [0.9671075338558173]
# matthews_correlation                                               [0.0]
# precision_score_macro                               [0.4440060698027314]
# norm_macro_recall                                                  [0.0]
# f1_score_weighted                                   [0.8353395018439429]
# f1_score_micro                                      [0.8880121396054628]
#
#                                  dd000e88-6004-4743-aa71-8b012b896dc8_13  \
# precision_score_weighted                            [0.8797028765180537]
# average_precision_score_weighted                    [0.9173670528251086]
# recall_score_macro                                  [0.7388403566195607]
# precision_score_micro                               [0.7359635811836115]
# accuracy                                            [0.7359635811836115]
# AUC_weighted                                        [0.8561407213525314]
# recall_score_micro                                  [0.7359635811836115]
# weighted_accuracy                                   [0.7352493556583243]
# average_precision_score_macro                       [0.7047750141658935]
# balanced_accuracy                                   [0.7388403566195607]
# AUC_macro                                           [0.8561407213525314]
# AUC_micro                                           [0.8379045825168496]
# log_loss                                             [0.582835913689048]
# recall_score_weighted                               [0.7359635811836115]
# f1_score_macro                                      [0.6091231727311104]
# average_precision_score_micro                       [0.8023187732955956]
# matthews_correlation                                [0.3233668011979279]
# precision_score_macro                               [0.6094518631576356]
# norm_macro_recall                                   [0.4776807132391214]
# f1_score_weighted                                   [0.7819153540912838]
# f1_score_micro                                      [0.7359635811836115]
#
#                                  dd000e88-6004-4743-aa71-8b012b896dc8_31  \
# precision_score_weighted                            [0.9171256626812081]
# average_precision_score_weighted                    [0.9371426556186387]
# recall_score_macro                                  [0.8566834677232623]
# precision_score_micro                                [0.844309559939302]
# accuracy                                             [0.844309559939302]
# AUC_weighted                                        [0.9235737162566432]
# recall_score_micro                                   [0.844309559939302]
# weighted_accuracy                                   [0.8412374533450867]
# average_precision_score_macro                       [0.7552172012800359]
# balanced_accuracy                                   [0.8566834677232623]
# AUC_macro                                           [0.9235737162566431]
# AUC_micro                                           [0.9111564171584757]
# log_loss                                            [0.4022087762935992]
# recall_score_weighted                                [0.844309559939302]
# f1_score_macro                                      [0.7310944783320217]
# average_precision_score_micro                       [0.8846466870185641]
# matthews_correlation                                [0.5273792571792039]
# precision_score_macro                               [0.6949409673219554]
# norm_macro_recall                                   [0.7133669354465246]
# f1_score_weighted                                   [0.8664971741551346]
# f1_score_micro                                       [0.844309559939302]
#
#                                  dd000e88-6004-4743-aa71-8b012b896dc8_34  \
# precision_score_weighted                            [0.9073413517247458]
# average_precision_score_weighted                    [0.9532949616277506]
# recall_score_macro                                  [0.7555631502999924]
# precision_score_micro                                [0.910773899848255]
# accuracy                                             [0.910773899848255]
# AUC_weighted                                        [0.9443444161030811]
# recall_score_micro                                   [0.910773899848255]
# weighted_accuracy                                   [0.9493085305813522]
# average_precision_score_macro                       [0.8160284053969975]
# balanced_accuracy                                   [0.7555631502999924]
# AUC_macro                                           [0.9443444161030812]
# AUC_micro                                           [0.9795210934855542]
# log_loss                                           [0.18540772116216425]
# recall_score_weighted                                [0.910773899848255]
# f1_score_macro                                       [0.766218666017978]
# average_precision_score_micro                        [0.980489021318208]
# matthews_correlation                                [0.5333475612263194]
# precision_score_macro                               [0.7782674465510286]
# norm_macro_recall                                   [0.5111263005999849]
# f1_score_weighted                                   [0.9088769959693552]
# f1_score_micro                                      [0.9107738998482551]
#
#                                  dd000e88-6004-4743-aa71-8b012b896dc8_7  \
# precision_score_weighted                           [0.8893802206722097]
# average_precision_score_weighted                   [0.9382224275138409]
# recall_score_macro                                 [0.7067585815981194]
# precision_score_micro                              [0.8955993930197269]
# accuracy                                           [0.8955993930197269]
# AUC_weighted                                       [0.9231235887205078]
# recall_score_micro                                 [0.8955993930197269]
# weighted_accuracy                                  [0.9424834584381944]
# average_precision_score_macro                      [0.7591042432473201]
# balanced_accuracy                                  [0.7067585815981194]
# AUC_macro                                          [0.9231235887205079]
# AUC_micro                                          [0.9669067723432524]
# log_loss                                          [0.23515912575605352]
# recall_score_weighted                              [0.8955993930197269]
# f1_score_macro                                     [0.7201383456983258]
# average_precision_score_micro                      [0.9612314591165053]
# matthews_correlation                                [0.442233772790718]
# precision_score_macro                              [0.7364723005510441]
# norm_macro_recall                                  [0.4135171631962389]
# f1_score_weighted                                  [0.8921022774732673]
# f1_score_micro                                     [0.8955993930197269]
#
#                                  dd000e88-6004-4743-aa71-8b012b896dc8_9  \
# precision_score_weighted                           [0.8778151035761835]
# average_precision_score_weighted                   [0.9388859252642329]
# recall_score_macro                                  [0.611026827971629]
# precision_score_micro                              [0.8980273141122913]
# accuracy                                           [0.8980273141122913]
# AUC_weighted                                       [0.9131976282168837]
# recall_score_micro                                 [0.8980273141122913]
# weighted_accuracy                                   [0.969281771589226]
# average_precision_score_macro                      [0.7689901172232319]
# balanced_accuracy                                   [0.611026827971629]
# AUC_macro                                          [0.9131976282168837]
# AUC_micro                                          [0.9710364487509239]
# log_loss                                          [0.24161680520481876]
# recall_score_weighted                              [0.8980273141122913]
# f1_score_macro                                     [0.6455019813875091]
# average_precision_score_micro                      [0.9707184375464654]
# matthews_correlation                              [0.34140430557176077]
# precision_score_macro                              [0.7624521072796935]
# norm_macro_recall                                   [0.222053655943258]
# f1_score_weighted                                  [0.8776872657374796]
# f1_score_micro                                     [0.8980273141122913]
#
#                                  dd000e88-6004-4743-aa71-8b012b896dc8_29  \
# precision_score_weighted                            [0.8959103648683194]
# average_precision_score_weighted                    [0.9470311070568083]
# recall_score_macro                                  [0.5675677553084485]
# precision_score_micro                               [0.9007587253414264]
# accuracy                                            [0.9007587253414264]
# AUC_weighted                                        [0.9281958591971429]
# recall_score_micro                                  [0.9007587253414264]
# weighted_accuracy                                   [0.9834810305373748]
# average_precision_score_macro                       [0.7969693494944702]
# balanced_accuracy                                   [0.5675677553084485]
# AUC_macro                                           [0.9281958591971429]
# AUC_micro                                           [0.9737530308717166]
# log_loss                                            [0.2292238675952688]
# recall_score_weighted                               [0.9007587253414264]
# f1_score_macro                                      [0.5923432191895104]
# average_precision_score_micro                       [0.9747660084035891]
# matthews_correlation                                [0.3187183462199802]
# precision_score_macro                               [0.8758500772797526]
# norm_macro_recall                                    [0.135135510616897]
# f1_score_weighted                                   [0.8675066697235122]
# f1_score_micro                                      [0.9007587253414264]
#
#                                  dd000e88-6004-4743-aa71-8b012b896dc8_35
# precision_score_weighted                             [0.890715328255867]
# average_precision_score_weighted                    [0.9511692332304503]
# recall_score_macro                                  [0.5514784744566515]
# precision_score_micro                               [0.8974203338391502]
# accuracy                                            [0.8974203338391502]
# AUC_weighted                                        [0.9388419311397488]
# recall_score_micro                                  [0.8974203338391502]
# weighted_accuracy                                   [0.9833083399548636]
# average_precision_score_macro                        [0.809271421992088]
# balanced_accuracy                                   [0.5514784744566515]
# AUC_macro                                           [0.9388419311397489]
# AUC_micro                                           [0.9755505767003392]
# log_loss                                           [0.23434562756300892]
# recall_score_weighted                               [0.8974203338391502]
# f1_score_macro                                      [0.5663771460965339]
# average_precision_score_micro                       [0.9767969945418868]
# matthews_correlation                               [0.27380985084401377]
# precision_score_macro                               [0.8640931244104392]
# norm_macro_recall                                  [0.10295694891330309]
# f1_score_weighted                                   [0.8603950103055891]
# f1_score_micro                                      [0.8974203338391502]
#
# [21 rows x 36 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/dd000e88-6004-4743-aa71-8b012b896dc8/model_data
# Downloaded azureml/dd000e88-6004-4743-aa71-8b012b896dc8/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                      importance_type='split',
#                                                                      learning_rate=0.1,
#                                                                      max_depth=-1,
#                                                                      min_child_samples=20,
#                                                                      min_child_weight=0.001,
#                                                                      min_split_gain=0.0,
#                                                                      n_estimators=100,
#                                                                      n_jobs=1,
#                                                                      num_leaves=31,
#                                                                      objective=None,
#                                                                      random_state=None,
#                                                                      reg_alpha=0.0,
#                                                                      reg_lambda=0.0,
#                                                                      silent=True,
#                                                                      subsample=1.0,
#                                                                      subsample_for_bin=200000,
#                                                                      subsample_freq=0,
#                                                                      verbose=-10))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('MaxAbsScaler', MaxAbsScaler(copy=True)),
#  ('LightGBMClassifier',
#   LightGBMClassifier(boosting_type='gbdt', class_weight=None,
#                      colsample_bytree=1.0, importance_type='split',
#                      learning_rate=0.1, max_depth=-1, min_child_samples=20,
#                      min_child_weight=0.001, min_split_gain=0.0, n_estimators=100,
#                      n_jobs=1, num_leaves=31, objective=None, random_state=None,
#                      reg_alpha=0.0, reg_lambda=0.0, silent=True, subsample=1.0,
#                      subsample_for_bin=200000, subsample_freq=0, verbose=-10))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_a766bde6_034e_11eb_89f8_000d3aed9439row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_a766bde6_034e_11eb_89f8_000d3aed9439row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_a766bde6_034e_11eb_89f8_000d3aed9439row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_a766bde6_034e_11eb_89f8_000d3aed9439row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_a766bde6_034e_11eb_89f8_000d3aed9439" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a766bde6_034e_11eb_89f8_000d3aed9439level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a766bde6_034e_11eb_89f8_000d3aed9439row0_col0" class="data row0 col0" >28431</td>
#                         <td id="T_a766bde6_034e_11eb_89f8_000d3aed9439row0_col1" class="data row0 col1" >827</td>
#             </tr>
#             <tr>
#                         <th id="T_a766bde6_034e_11eb_89f8_000d3aed9439level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a766bde6_034e_11eb_89f8_000d3aed9439row1_col0" class="data row1 col0" >1246</td>
#                         <td id="T_a766bde6_034e_11eb_89f8_000d3aed9439row1_col1" class="data row1 col1" >2446</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: 41ddea8f-ee4f-4729-897d-049e87cc6d67,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/bc4ac49b-f3f0-45bb-995b-638f2c80696f/resourceGroups/aml-quickstarts-117869/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-117869/PipelineRuns/PipelineSubmit/41ddea8f-ee4f-4729-897d-049e87cc6d67)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  cb1010f7-0355-44d5-9386-3db4690da3ef

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
